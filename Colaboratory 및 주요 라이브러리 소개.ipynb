# %% [markdown]
# ## Google Colaboratory 소개

# %% [markdown]
# 구글에서 Google Drive 기반으로 제공하는 서비스로, 아래와 같은 특징을 가지고 있습니다.
#
# - 하드웨어 구성이 필요하지 않음
# - GPU를 무료로 사용 가능
# - 작업 산출물의 간편한 공유
#
# **학생**이 공부를 목적으로 하는 것 외에도, **데이터 사이언티스트**와 **AI 연구원**이 실무에서도 간편히 업무를 처리할 수 있습니다.

# %% [markdown]
# ### **Colab Notebook의 구성**

# %% [markdown]
# Colab Notebook에는 `코드 셀`과 `텍스트 셀`을 사용할 수 있습니다. 각 셀은 아래의 기능을 이용할 수 있습니다. Colab Notebook은 기본적으로 Colab에서 호스팅하는 커스텀 Jupyter Notebook입니다. Colab을 더욱 잘 사용하고 싶으면, [jupyter.org](http://jupyter.org)를 참조하세요.
#
# - 코드 셀
#   - Interactive Python 코드 편집기
#   - %로 시작하는 매직 커맨드 (`%lsmagic`으로 확인)
#   - !로 시작하는 쉘 커맨드 (Linux Ubuntu 18.04 LTS)
#
# - 텍스트 셀
#   - Markdown, HTML, LaTeX 텍스트 편집기
#   - 이미지 업로드 및 렌더링

# %% [markdown]
# ### **Colab의 운영체제**

# %% [markdown]
# Google Colab에서는 **Ubuntu 버전의 리눅스**를 사용합니다. Ubuntu 리눅스는 서버 기반의 **머신러닝**과 **딥러닝** 애플리케이션을 구동하는 데에 가장 많이 사용되는 운영체제입니다.
#
# `코드 셀`에서 첫머리에 `!`를 삽입하여 쉘 커맨드로 운영체제에 직접 명령을 내릴 수 있습니다. 쉘 커맨드는 윈도우즈의 cmd와 유사하게 텍스트 기반으로 운영체제를 사용하는 프로그램입니다.

# %%
# !cat /etc/os-release

# %% [markdown]
# ### **Colab에 설치된 Python 패키지**

# %% [markdown]
# Colab에는 현재 Python 3.7.12 버전이 설치되어 있으며, `!python --version`을 통해 언제든지 현재 런타임의 버전을 확인할 수 있습니다.

# %%
# !python --version
# Out:
# Python 3.7.12

# %% [markdown]
# Colab에 설치된 Python에는 데이터 사이언티스트를 위한 대부분의 패키지가 설치되어 있습니다. 대표적으로 아래와 같은 패키지가 설치되어 있으며, `!pip list`를 통해 확인할 수 있습니다.
#
# - numpy: matrix, n차원 행렬 (ndarray) 등 수학적 표현, 연산
# - pandas: 테이블 형태의 자료형 DataFrame을 제공, 연산 가능 패키지
#
# <시각화>
# - matplotlib, seaborn: 데이터 시각화
# - plotly: 웹에서 상호작용 가능한 그래프를 만들어주는 오픈소스 패키지
# - yellowbrick: 시각화 라이브러리
#
# <머신러닝>
# - scikit-learn, xgboost, lightgbm: 머신러닝
# - fbprophet : facebook제공, 시계열 data 머신러닝
#
# <딥러닝>
# - keras, tensorflow, theano, pytorch: 딥러닝 라이브러리.
#
# - kaggle: 캐글 데이터셋 서비스 사용 위한 캐글 접속 위한 API
#
# - opencv: open computer vision library. C, C++로 구현되어있으며 파이썬으로 랩핑되어 들어가 있음. 동영상 처리, 이미지 처리에 활용

# %%
# !pip list

# %% [markdown]
# #### Numpy 패키지

# %% [markdown]
# Numpy는 파이썬에서 가장 많이 사용되는 수치 계산 라이브러리입니다. 벡터와 행렬 등 수학적인 데이터 구조를 표현하고, 연산하는 기본적인 기능이 효율적으로 구현되어 있습니다. 우리가 사용하는 대부분의 패키지가 numpy에 의존하고 있습니다.

# %%
import numpy as np

# %%
matrix_a = np.asarray([[4, 5, 2],
                       [5, 2, 6],
                       [6, 1, -2]])

matrix_b = np.asarray([[5, 9, 2],
                       [2, 0, 3],
                       [1, -4, 5]])

matrix_c = matrix_a + matrix_b
print(matrix_c)
# Out:
# [[ 9 14  4]
#  [ 7  2  9]
#  [ 7 -3  3]]

# %%
delete

# %% [markdown]
# #### Pandas 패키지

# %% [markdown]
# Pandas는 numpy를 기반으로, 보다 고차원적인 데이터 처리를 돕는 라이브러리입니다. 동일한 데이터를 가진 Series를 기본으로 하며, 이를 여러개 묶어 사용하는 DataFrame을 사용하여 표 형태로 된 자료를 다룹니다.

# %%
import pandas as pd

# %%
col_id = pd.Series(data=[5, 14, 21, 25])
col_team = pd.Series(data=['A', 'A', 'B', 'B'])
col_name = pd.Series(data=['김가나', '정다라', '박마바', '빅마마'])
col_score = pd.Series(data=[100, 95, 60, 80])

df = pd.DataFrame(data={'Id': col_id,
                        'Team': col_team,
                        'Name': col_name,
                        'Score': col_score})
df.set_index('Id', inplace=True) # 인덱스 처리
df
# Out:
#    Team Name  Score
# Id
# 5     A  김가나    100
# 14    A  정다라     95
# 21    B  박마바     60
# 25    B  빅마마     80

# %%
# 같은 팀끼리 모아서 평균 계산
df.groupby('Team').mean()
# Out:
#       Score
# Team
# A      97.5
# B      70.0

# %% [markdown]
# #### Matplotlib 패키지

# %% [markdown]
# Matplotlib은 Python에서 Matlab 스타일의 그래프를 그리기 위해서 만들어진 오픈소스 패키지입니다. 각종 그래프를 표현할 수 있는 기반이 되며, 자세한 내용은 [matplotlib.org](https://matplotlib.org/)에서 확인할 수 있습니다.

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 1, 100) #linear space의 약자. 0과 1사이를 100개로 쪼개서 x에 넣음
y = x
yy = x ** 2

fig = plt.figure()
ax = fig.gca()
ax.plot(x, y, 'r-') # y = x
ax.plot(x, yy, 'g-') # y = y^2
ax.set_title('Title') # 제목
ax.set_xlabel('x') # x축 이름
ax.set_ylabel('y') # y축 이름
ax.legend(['y = x', 'y = x^2']) # 범례
ax.grid()
fig.show()

# %% [markdown]
# #### Seaborn 패키지

# %% [markdown]
# Seaborn은 matplotlib 패키지를 기반으로 하여 보다 편하게 통계를 시각화할 수 있는 도구입니다. 일반적으로 데이터 사이언스에서 사용하는 대부분의 그래프를 지원합니다.
# https://seaborn.pydata.org/index.html

# %%
import seaborn as sns

# %%
sns.histplot(x = 'Score', data = df, bins = 20)

# %%
sns.histplot(x = 'Score', data = df, bins = 5)

# %%
# 팀별 점수 영역대 확인 - histplot의 hue 이용
sns.histplot(x='Score', data=df, hue='Team')

# %%
# 팀별 점수 영역대 확인 - boxplot 이용
sns.boxplot(y='Score', x='Team', data=df)

# %% [markdown]
# #### Plotly 패키지

# %% [markdown]
# Plotly 패키지는 Plotly 사에서 개발, 서비스하는 반응형 그래프 생성 엔진입니다. 클라우드 기반의 엔터프라이즈 서비스는 유료로 제공되지만, 로컬에서 사용하는 개인용 라이브러리는 오픈소스로 제공되어 무료로 사용할 수 있습니다. 자세한 내용은 [plotly.com](https://plotly.com/python/)에서 확인할 수 있습니다.

# %%
import plotly.express as px

# %%
fig = px.line(x=["a","b","c"], y=[1,3,2], title="sample figure")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="07264619-8370-406b-989c-2b657f59362f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("07264619-8370-406b-989c-2b657f59362f")) {
#                     Plotly.newPlot(
#                         '07264619-8370-406b-989c-2b657f59362f',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": ["a", "b", "c"], "xaxis": "x", "y": [1, 3, 2], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %% [markdown]
# #### Kaggle

# %% [markdown]
# dataset kernel, challenge, competition을 경험 가능
#
# https://www.kaggle.com/
#
# 구글 아이디로 가입 가능
